# %%
import pandas as pd
data = pd.read_csv('fifa21_train.csv')

import functions # this imports a function saves as a .py file in the same directory
data
# Out:
#            ID            Name  Age  Nationality                        Club  \
# 0      184383       A. Pasche   26  Switzerland           FC Lausanne-Sport
# 1      188044   Alan Carvalho   30     China PR     Beijing Sinobo Guoan FC
# 2      184431     S. Giovinco   33        Italy                    Al Hilal
# 3      233796        J. Evans   22        Wales                Swansea City
# 4      234799      Y. Demoncy   23       France  US Orléans Loiret Football
# ...       ...             ...  ...          ...                         ...
# 11696  232504   B. Böðvarsson   25      Iceland       Jagiellonia Białystok
# 11697  214680       G. Gallon   27       France                ESTAC Troyes
# 11698  221489       J. Flores   22        Chile              CD Antofagasta
# 11699  146717  Anderson Silva   26       Brazil                    Barnsley
# 11700  236507     T. Conechny   22    Argentina            Portland Timbers
#
# ...

# %%
data2 = functions.clean_data(data)
data2
# Out:
#         BP  Age  Height  Weight   foot  Growth      Value  Attacking  Skill  \
# 0       CM   26  175.26     161  Right       1   525000.0        258    286
# 1       ST   30  182.88     159  Right       0  8500000.0        365    375
# 2      CAM   33  162.56     134  Right       0  9000000.0        336    424
# 3      CDM   22  177.80     152  Right      13   275000.0        242    259
# 4      CDM   23  180.34     150  Right       8   725000.0        249    280
# ...    ...  ...     ...     ...    ...     ...        ...        ...    ...
# 11696   LB   25  185.42     168   Left       5   625000.0        224    248
# 11697   GK   27  185.42     174  Right       4  1600000.0         84     96
# 11698   RM   22  167.64     143  Right       8  1100000.0        286    291
# 11699   CM   26  187.96     179  Right       7        0.0        254    284
# 11700  CAM   22  170.18     143   Left       9   700000.0        289    267
#
# ...

# %%
y,X = functions.y_X(data2,'OVA')
display(y)
X
# Out:
# 0        64
# 1        77
# 2        80
# 3        59
# 4        65
#          ..
# 11696    65
# 11697    70
# 11698    67
# 11699    68
# 11700    64
# Name: OVA, Length: 11701, dtype: int64
#             Age  Height    Weight    Growth     Value  Attacking     Skill  \
# 0      0.370370    0.40  0.349206  0.074074  0.005833   0.556931  0.569087
# 1      0.518519    0.55  0.333333  0.037037  0.094444   0.821782  0.777518
# 2      0.629630    0.15  0.134921  0.037037  0.100000   0.750000  0.892272
# 3      0.222222    0.45  0.277778  0.518519  0.003056   0.517327  0.505855
# 4      0.259259    0.50  0.261905  0.333333  0.008056   0.534653  0.555035
# ...         ...     ...       ...       ...       ...        ...       ...
# 11696  0.333333    0.60  0.404762  0.222222  0.006944   0.472772  0.480094
# 11697  0.407407    0.60  0.452381  0.185185  0.017778   0.126238  0.124122
# 11698  0.222222    0.25  0.206349  0.333333  0.012222   0.626238  0.580796
# ...
